# %% [markdown]
# # **Convolution Neural Networks(CNNs) can be used to add relativistic corrections to Newtonian simulations**

# %% [markdown]
# #**Pipeline Scheme**

# %% [markdown]
# ![CNNs - Support process example.jpeg](data:im
# age/jpeg;base64,...)

# %% [markdown]
# #**Machine leaning model**

# %% [markdown]
# ![cnn.png](data:image/png;base64,...)
